# %% [markdown]
# ![identificadores_centrados_en_ti_logo-h.png](data:image/png;base64,...)

# %% [markdown]
# ---
# # Importación de información.
# ---
# Los datos vienen comunmente en formatos excel, csv, txt, o quizá esté en alguna url. Aunque estos pueden estar en otro formato (JSON, API'S) nos centraremos en los tres primeros.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd "/content/drive/MyDrive/Ucentral_Maestría/Año_2024/Fundamentos_GR04/Fundamentos_Estadistica_Analitica_GR04/Intro_Python"
# Out:
# /content/drive/MyDrive/Ucentral_Maestría/Año_2024/Fundamentos_GR04/Fundamentos_Estadistica_Analitica_GR04/Intro_Python

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Ucentral_Maestría/Año_2024/Fundamentos_GR04/Fundamentos_Estadistica_Analitica_GR04/Intro_Python

# %%
# !ls "data"
# Out:
#  Athelete_Country_Map.csv   downloaded_medals.csv    Medals.csv
#  Athelete_Sports_Map.csv    downloaded_medals.json   mi_descarga.xlsx
#  CARS2005.SAV		    downloaded_medals.xls   'Winter Olympic Medals.xlsx'

# %%
## Librerías requeridas
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
# Número de columnas máximo a mostrar. None se reemplaza por el # máximo de columnas.

# %%
df_csv = pd.read_csv("../data/downloaded_medals.csv", sep=",")
df_csv
# Out:
#       Unnamed: 0      City      Discipline            Event Event gender  \
# 0              0  Chamonix  Figure skating       individual            M
# 1              1  Chamonix  Figure skating       individual            W
# 2              2  Chamonix  Figure skating            pairs            X
# 3              3  Chamonix       Bobsleigh         four-man            M
# 4              4  Chamonix      Ice Hockey       ice hockey            M
# ...          ...       ...             ...              ...          ...
# 2306        2306     Turin       Snowboard        Half-pipe            M
# 2307        2307     Turin       Snowboard        Half-pipe            W
# 2308        2308     Turin       Snowboard        Half-pipe            W
# 2309        2309     Turin       Snowboard  Snowboard Cross            M
# 2310        2310     Turin       Snowboard  Snowboard Cross            W
#
#        Medal  NOC       Sport  Year
# 0     Silver  AUT     Skating  1924
# ...

# %%
## Función .head() muestra los 5 primeros elementos
df_csv = pd.read_csv("../data/downloaded_medals.csv", index_col=[0], sep=",")
df_csv.head()
# Out:
#        City      Discipline       Event Event gender   Medal  NOC       Sport  \
# 0  Chamonix  Figure skating  individual            M  Silver  AUT     Skating
# 1  Chamonix  Figure skating  individual            W    Gold  AUT     Skating
# 2  Chamonix  Figure skating       pairs            X    Gold  AUT     Skating
# 3  Chamonix       Bobsleigh    four-man            M  Bronze  BEL   Bobsleigh
# 4  Chamonix      Ice Hockey  ice hockey            M    Gold  CAN  Ice Hockey
#
#    Year
# 0  1924
# 1  1924
# 2  1924
# 3  1924
# 4  1924

# %%
df_csv
# Out:
#           City      Discipline            Event Event gender   Medal  NOC  \
# 0     Chamonix  Figure skating       individual            M  Silver  AUT
# 1     Chamonix  Figure skating       individual            W    Gold  AUT
# 2     Chamonix  Figure skating            pairs            X    Gold  AUT
# 3     Chamonix       Bobsleigh         four-man            M  Bronze  BEL
# 4     Chamonix      Ice Hockey       ice hockey            M    Gold  CAN
# ...        ...             ...              ...          ...     ...  ...
# 2306     Turin       Snowboard        Half-pipe            M  Silver  USA
# 2307     Turin       Snowboard        Half-pipe            W    Gold  USA
# 2308     Turin       Snowboard        Half-pipe            W  Silver  USA
# 2309     Turin       Snowboard  Snowboard Cross            M    Gold  USA
# 2310     Turin       Snowboard  Snowboard Cross            W  Silver  USA
#
#            Sport  Year
# 0        Skating  1924
# 1        Skating  1924
# ...

# %%
df_csv.columns
# Out:
# Index(['City', 'Discipline', 'Event', 'Event gender', 'Medal', 'NOC', 'Sport',
#        'Year'],
#       dtype='object')

# %%
df_csv.rename(columns={"City": "Ciudad", "Event": "Evento"})
# Out:
#         Ciudad      Discipline           Evento Event gender   Medal  NOC  \
# 0     Chamonix  Figure skating       individual            M  Silver  AUT
# 1     Chamonix  Figure skating       individual            W    Gold  AUT
# 2     Chamonix  Figure skating            pairs            X    Gold  AUT
# 3     Chamonix       Bobsleigh         four-man            M  Bronze  BEL
# 4     Chamonix      Ice Hockey       ice hockey            M    Gold  CAN
# ...        ...             ...              ...          ...     ...  ...
# 2306     Turin       Snowboard        Half-pipe            M  Silver  USA
# 2307     Turin       Snowboard        Half-pipe            W    Gold  USA
# 2308     Turin       Snowboard        Half-pipe            W  Silver  USA
# 2309     Turin       Snowboard  Snowboard Cross            M    Gold  USA
# 2310     Turin       Snowboard  Snowboard Cross            W  Silver  USA
#
#            Sport  Year
# 0        Skating  1924
# 1        Skating  1924
# ...

# %%
## Función .tail() muestra los 5 últimos elementos
df_csv = pd.read_csv("../data/downloaded_medals.csv", index_col=[0])
df_csv.tail(10)
# Out:
#        City      Discipline                  Event Event gender   Medal  NOC  \
# 2301  Turin   Alpine Skiing        Alpine combined            M    Gold  USA
# 2302  Turin   Alpine Skiing           giant slalom            W    Gold  USA
# 2303  Turin  Freestyle Ski.                 moguls            M  Bronze  USA
# 2304  Turin       Snowboard  Giant parallel slalom            W  Bronze  USA
# 2305  Turin       Snowboard              Half-pipe            M    Gold  USA
# 2306  Turin       Snowboard              Half-pipe            M  Silver  USA
# 2307  Turin       Snowboard              Half-pipe            W    Gold  USA
# 2308  Turin       Snowboard              Half-pipe            W  Silver  USA
# 2309  Turin       Snowboard        Snowboard Cross            M    Gold  USA
# 2310  Turin       Snowboard        Snowboard Cross            W  Silver  USA
#
#        Sport  Year
# 2301  Skiing  2006
# 2302  Skiing  2006
# 2303  Skiing  2006
# 2304  Skiing  2006
# 2305  Skiing  2006
# ...

# %%
## Sample
df_csv.sample(frac=0.01)
# Out:
#                         City       Discipline          Event Event gender  \
# 119              Lake Placid  Cross Country S           18km            M
# 1035                Sarajevo             Luge        doubles            X
# 1812                  Nagano       Ice Hockey     ice hockey            W
# 1015                Sarajevo    Speed skating           500m            M
# 1224                 Calgary  Cross Country S           50km            M
# 2035          Salt Lake City   Figure skating     individual            M
# 769                  Sapporo  Cross Country S           10km            W
# 179   Garmisch-Partenkirchen        Bobsleigh        two-man            M
# 641                 Grenoble        Bobsleigh        two-man            M
# 1483             Lillehammer         Biathlon  4x7.5km relay            W
# 1332             Albertville    Alpine Skiing        super-G            W
# 128              Lake Placid    Speed skating          1500m            M
# ...

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2311 entries, 0 to 2310
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2311 non-null   object
#  1   Discipline    2311 non-null   object
#  2   Event         2311 non-null   object
#  3   Event gender  2311 non-null   object
#  4   Medal         2311 non-null   object
#  5   NOC           2311 non-null   object
#  6   Sport         2311 non-null   object
#  7   Year          2311 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 162.5+ KB

# %%
df_csv.isna().sum(axis=0).to_frame(name="count_nan").T
# Out:
#            City  Discipline  Event  Event gender  Medal  NOC  Sport  Year
# count_nan     0           0      0             0      0    0      0     0

# %% [markdown]
# ---
# ## Archivos excel
# ---

# %%
df_excel = pd.read_excel("../data/downloaded_medals.xls")
df_excel
# Out:
#       Unnamed: 0      City      Discipline            Event Event gender  \
# 0              0  Chamonix  Figure skating       individual            M
# 1              1  Chamonix  Figure skating       individual            W
# 2              2  Chamonix  Figure skating            pairs            X
# 3              3  Chamonix       Bobsleigh         four-man            M
# 4              4  Chamonix      Ice Hockey       ice hockey            M
# ...          ...       ...             ...              ...          ...
# 2306        2306     Turin       Snowboard        Half-pipe            M
# 2307        2307     Turin       Snowboard        Half-pipe            W
# 2308        2308     Turin       Snowboard        Half-pipe            W
# 2309        2309     Turin       Snowboard  Snowboard Cross            M
# 2310        2310     Turin       Snowboard  Snowboard Cross            W
#
#        Medal  NOC       Sport  Year
# 0     Silver  AUT     Skating  1924
# ...

# %%
dict_excel_sheets = pd.read_excel("../data/downloaded_medals.xls", sheet_name=None)
dict_excel_sheets
# Out:
# {'Sheet1':       Unnamed: 0      City      Discipline            Event Event gender  \
#  0              0  Chamonix  Figure skating       individual            M
#  1              1  Chamonix  Figure skating       individual            W
#  2              2  Chamonix  Figure skating            pairs            X
#  3              3  Chamonix       Bobsleigh         four-man            M
#  4              4  Chamonix      Ice Hockey       ice hockey            M
#  ...          ...       ...             ...              ...          ...
#  2306        2306     Turin       Snowboard        Half-pipe            M
#  2307        2307     Turin       Snowboard        Half-pipe            W
#  2308        2308     Turin       Snowboard        Half-pipe            W
#  2309        2309     Turin       Snowboard  Snowboard Cross            M
#  2310        2310     Turin       Snowboard  Snowboard Cross            W
#
#         Medal  NOC       Sport  Year
# ...

# %%
df_sheet1 = dict_excel_sheets["Sheet1"]
df_sheet1
# Out:
#       Unnamed: 0      City      Discipline            Event Event gender  \
# 0              0  Chamonix  Figure skating       individual            M
# 1              1  Chamonix  Figure skating       individual            W
# 2              2  Chamonix  Figure skating            pairs            X
# 3              3  Chamonix       Bobsleigh         four-man            M
# 4              4  Chamonix      Ice Hockey       ice hockey            M
# ...          ...       ...             ...              ...          ...
# 2306        2306     Turin       Snowboard        Half-pipe            M
# 2307        2307     Turin       Snowboard        Half-pipe            W
# 2308        2308     Turin       Snowboard        Half-pipe            W
# 2309        2309     Turin       Snowboard  Snowboard Cross            M
# 2310        2310     Turin       Snowboard  Snowboard Cross            W
#
#        Medal  NOC       Sport  Year
# 0     Silver  AUT     Skating  1924
# ...

# %%
# Archivos Excel
obj_Excel= pd.ExcelFile("../data/downloaded_medals.xls")
obj_Excel.sheet_names
# Out:
# ['Sheet1']

# %%
df_Excel = obj_Excel.parse("Sheet1")
df_Excel.drop(columns=["Unnamed: 0"])
# Out:
#           City      Discipline            Event Event gender   Medal  NOC  \
# 0     Chamonix  Figure skating       individual            M  Silver  AUT
# 1     Chamonix  Figure skating       individual            W    Gold  AUT
# 2     Chamonix  Figure skating            pairs            X    Gold  AUT
# 3     Chamonix       Bobsleigh         four-man            M  Bronze  BEL
# 4     Chamonix      Ice Hockey       ice hockey            M    Gold  CAN
# ...        ...             ...              ...          ...     ...  ...
# 2306     Turin       Snowboard        Half-pipe            M  Silver  USA
# 2307     Turin       Snowboard        Half-pipe            W    Gold  USA
# 2308     Turin       Snowboard        Half-pipe            W  Silver  USA
# 2309     Turin       Snowboard  Snowboard Cross            M    Gold  USA
# 2310     Turin       Snowboard  Snowboard Cross            W  Silver  USA
#
#            Sport  Year
# 0        Skating  1924
# 1        Skating  1924
# ...

# %% [markdown]
# ---
# ## Archivos JSON
# ---

# %%
df_json = pd.read_json("../data/downloaded_medals.json")
df_json.head()
# Out:
#        City      Discipline       Event Event gender   Medal  NOC       Sport  \
# 0  Chamonix  Figure skating  individual            M  Silver  AUT     Skating
# 1  Chamonix  Figure skating  individual            W    Gold  AUT     Skating
# 2  Chamonix  Figure skating       pairs            X    Gold  AUT     Skating
# 3  Chamonix       Bobsleigh    four-man            M  Bronze  BEL   Bobsleigh
# 4  Chamonix      Ice Hockey  ice hockey            M    Gold  CAN  Ice Hockey
#
#    Year
# 0  1924
# 1  1924
# 2  1924
# 3  1924
# 4  1924

# %% [markdown]
# ---
# ### Ejercicio 1
# ---
# Importar el archivo `'Winter Olympic Medals.xlsx'` y definir en cada caso un dataframe para cada hoja. Además en cada caso, mostrar su cabeza y su cola.

# %% [markdown]
# **Respuesta:**

# %%
# Su código acá
excel_file = pd.ExcelFile("../data/Winter Olympic Medals.xlsx")
excel_file.sheet_names
# Out:
# ['Data', 'Ranks', 'Sources']

# %%
df_data = excel_file.parse("Data")
df_data.head()
# Out:
#    Year                 Sport                Event      Country Gender  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
#
#    Medal Rank   Medal Name of Athlete or Team  Age of Athlete
# 0           1    gold           Switzerland-1             NaN
# 1           2  silver               Britain-1             NaN
# 2           3  bronze               Belgium-1             NaN
# 3           1    gold           Thorleif Haug            29.0
# 4           2  silver  Johan GrÃ¸ttumsbraaten            24.0

# %%
df_ranks = excel_file.parse("Ranks")
df_ranks.head()
# Out:
#        Country  Rank asc  Rank desc
# 0      Romania         1         44
# 1  New Zealand         2         43
# 2      Denmark         3         42
# 3   Uzbekistan         4         41
# 4  North Korea         5         40

# %%
df_source = excel_file.parse("Sources")
df_source.head()
# Out:
#             Sources
# 0          LA Times
# 1  Sports-Reference
# 2         Wikipedia

# %% [markdown]
# ---
# ## Desde una URL
# ---

# %%
## Dependerá de donde y como estén los datos.
df_url = pd.read_excel("https://query.data.world/s/zilmgkqzxjhjrfn2pllc4dhikcvrzt")
display(df_url.head())
df_url.to_excel("../data/mi_descarga.xlsx", index=False)
# Out:
#    Year                 Sport                Event      Country Gender  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
#
#    Medal Rank   Medal Name of Athlete or Team  Age of Athlete
# 0           1    gold           Switzerland-1             NaN
# 1           2  silver               Britain-1             NaN
# 2           3  bronze               Belgium-1             NaN
# 3           1    gold           Thorleif Haug            29.0
# 4           2  silver  Johan GrÃ¸ttumsbraaten            24.0

# %% [markdown]
# ---
# # VAMOS ACÁ
# ---

# %%
url = "https://raw.githubusercontent.com/lacamposm/Fundamentos_Analitica/main/data/titanic3.csv"
df_url_1 = pd.read_csv(url)
df_url_1.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ---
# ## Información del `dataframe`
# ---

# %%
# Copiamos un dataframe
df = df_url.copy()
df.head(5)
# Out:
#    Year                 Sport                Event      Country Gender  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
#
#    Medal Rank   Medal Name of Athlete or Team  Age of Athlete
# 0           1    gold           Switzerland-1             NaN
# 1           2  silver               Britain-1             NaN
# 2           3  bronze               Belgium-1             NaN
# 3           1    gold           Thorleif Haug            29.0
# 4           2  silver  Johan GrÃ¸ttumsbraaten            24.0

# %%
## Nombres columnas
df.columns
# Out:
# Index(['Year', 'Sport', 'Event', 'Country', 'Gender', 'Medal Rank', 'Medal',
#        'Name of Athlete or Team', 'Age of Athlete'],
#       dtype='object')

# %%
for column in df.columns:
    print(column, "--->", df[column].dtype)
    print(df[column].head())
    print()
# Out:
# Year ---> int64
# 0    1924
# 1    1924
# 2    1924
# 3    1924
# 4    1924
# Name: Year, dtype: int64
#
# Sport ---> object
# 0                 Bobsled
# 1                 Bobsled
# 2                 Bobsled
# 3    Cross-Country Skiing
# 4    Cross-Country Skiing
# Name: Sport, dtype: object
#
# Event ---> object
# 0        Men's Four/Five
# 1        Men's Four/Five
# 2        Men's Four/Five
# 3    Men's 18 Kilometers
# 4    Men's 18 Kilometers
# Name: Event, dtype: object
#
# Country ---> object
# 0    Switzerland
# 1        Britain
# 2        Belgium
# 3         Norway
# 4         Norway
# Name: Country, dtype: object
#
# Gender ---> object
# 0    Men
# 1    Men
# 2    Men
# 3    Men
# 4    Men
# Name: Gender, dtype: object
#
# Medal Rank ---> int64
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
# Name: Medal Rank, dtype: int64
#
# Medal ---> object
# 0      gold
# 1    silver
# 2    bronze
# 3      gold
# 4    silver
# Name: Medal, dtype: object
#
# ...

# %%
## Tipos de datos en el dataframe
df.dtypes
# Out:
# Year                         int64
# Sport                       object
# Event                       object
# Country                     object
# Gender                      object
# Medal Rank                   int64
# Medal                       object
# Name of Athlete or Team     object
# Age of Athlete             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2865 entries, 0 to 2864
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     2865 non-null   int64
#  1   Sport                    2865 non-null   object
#  2   Event                    2865 non-null   object
#  3   Country                  2865 non-null   object
#  4   Gender                   2865 non-null   object
#  5   Medal Rank               2865 non-null   int64
#  6   Medal                    2865 non-null   object
#  7   Name of Athlete or Team  2865 non-null   object
#  8   Age of Athlete           2173 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 201.6+ KB

# %%
# pd.read_csv(
    # "https://raw.githubusercontent.com/lacamposm/Fundamentos_Analitica/main/data/TABLA_PERSONAS.csv",
    # sep=";",
    # decimal=","
# ).info()

# %%
## pd.DataFrame con las columnas de tipo 'int64'.
df.select_dtypes(include=["int64"])
# Out:
#       Year  Medal Rank
# 0     1924           1
# 1     1924           2
# 2     1924           3
# 3     1924           1
# 4     1924           2
# ...    ...         ...
# 2860  2014           1
# 2861  2014           2
# 2862  2014           3
# 2863  2014           1
# 2864  2014           2
#
# [2865 rows x 2 columns]

# %%
## pd.DataFrame con las columnas numéricas.
df.select_dtypes(np.number)
# Out:
#       Year  Medal Rank  Age of Athlete
# 0     1924           1             NaN
# 1     1924           2             NaN
# 2     1924           3             NaN
# 3     1924           1            29.0
# 4     1924           2            24.0
# ...    ...         ...             ...
# 2860  2014           1            30.0
# 2861  2014           2            31.0
# 2862  2014           3            27.0
# 2863  2014           1             NaN
# 2864  2014           2             NaN
#
# [2865 rows x 3 columns]

# %%
df.dtypes
# Out:
# Year                         int64
# Sport                       object
# Event                       object
# Country                     object
# Gender                      object
# Medal Rank                   int64
# Medal                       object
# Name of Athlete or Team     object
# Age of Athlete             float64
# dtype: object

# %%
## pd.DataFrame con las columnas tipo object.
df.select_dtypes("object")
# Out:
#                      Sport                Event      Country Gender   Medal  \
# 0                  Bobsled      Men's Four/Five  Switzerland    Men    gold
# 1                  Bobsled      Men's Four/Five      Britain    Men  silver
# 2                  Bobsled      Men's Four/Five      Belgium    Men  bronze
# 3     Cross-Country Skiing  Men's 18 Kilometers       Norway    Men    gold
# 4     Cross-Country Skiing  Men's 18 Kilometers       Norway    Men  silver
# ...                    ...                  ...          ...    ...     ...
# 2860  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men    gold
# 2861  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men  silver
# 2862  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men  bronze
# 2863            Ice Hockey     Men's Ice Hockey       Canada    Men    gold
# 2864            Ice Hockey     Men's Ice Hockey       Sweden    Men  silver
#
#      Name of Athlete or Team
# ...

# %%
df.describe().T # df.describe.transpose()
# Out:
#                  count         mean        std     min     25%     50%  \
# Year            2865.0  1986.488656  23.489775  1924.0  1972.0  1992.0
# Medal Rank      2865.0     1.995812   0.815773     1.0     1.0     2.0
# Age of Athlete  2173.0    25.152324   4.271764    14.0    22.0    25.0
#
#                    75%     max
# Year            2006.0  2014.0
# Medal Rank         3.0     3.0
# Age of Athlete    28.0    42.0

# %%
df.describe(include=["object"]).T # df.describe.transpose()
# Out:
#                         count unique            top  freq
# Sport                    2865     15   Speedskating   527
# Event                    2865    127  Men's Singles   108
# Country                  2865     44         Norway   329
# Gender                   2865      3            Men  1711
# Medal                    2865      3           gold   959
# Name of Athlete or Team  2865   1430         Canada    49

# %%
type_variables = ["object", "int64"]
##
for type_var in type_variables:
    print("Descripción de las variables de tipo", type_var, ":")
    display(df.describe(include=type_var).T)
    print("="*100)
# Out:
# Descripción de las variables de tipo object :
#                         count unique            top  freq
# Sport                    2865     15   Speedskating   527
# Event                    2865    127  Men's Singles   108
# Country                  2865     44         Norway   329
# Gender                   2865      3            Men  1711
# Medal                    2865      3           gold   959
# Name of Athlete or Team  2865   1430         Canada    49
# ...
# Descripción de las variables de tipo int64 :
#              count         mean        std     min     25%     50%     75%  \
# Year        2865.0  1986.488656  23.489775  1924.0  1972.0  1992.0  2006.0
# Medal Rank  2865.0     1.995812   0.815773     1.0     1.0     2.0     3.0
#
#                max
# Year        2014.0
# Medal Rank     3.0
# ...

# %%
df = df_url.copy()
display(df.head(5))
print()
mapper_cols_names = {
    "Event":"Evento",
    "Gender":"Género",
    "Medal":"Medalla",
    "Age of Athlete":"Edad_Atleta",
    "Name of Athlete or Team":"Nombre_atleta_o_Equipo"
}

df = df.rename(columns=mapper_cols_names)
df.head()
# Out:
#    Year                 Sport                Event      Country Gender  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
#
#    Medal Rank   Medal Name of Athlete or Team  Age of Athlete
# 0           1    gold           Switzerland-1             NaN
# 1           2  silver               Britain-1             NaN
# 2           3  bronze               Belgium-1             NaN
# 3           1    gold           Thorleif Haug            29.0
# 4           2  silver  Johan GrÃ¸ttumsbraaten            24.0
#    Year                 Sport               Evento      Country Género  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# ...

# %% [markdown]
# ---
# ## Sub dataframes
# ---

# %%
df
# Out:
#       Year                 Sport               Evento      Country Género  \
# 0     1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1     1924               Bobsled      Men's Four/Five      Britain    Men
# 2     1924               Bobsled      Men's Four/Five      Belgium    Men
# 3     1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4     1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# ...    ...                   ...                  ...          ...    ...
# 2860  2014  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men
# 2861  2014  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men
# 2862  2014  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men
# 2863  2014            Ice Hockey     Men's Ice Hockey       Canada    Men
# 2864  2014            Ice Hockey     Men's Ice Hockey       Sweden    Men
#
#       Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
## Serie de pandas
display(df["Edad_Atleta"])
type(df["Edad_Atleta"])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3       29.0
# 4       24.0
#         ...
# 2860    30.0
# 2861    31.0
# 2862    27.0
# 2863     NaN
# 2864     NaN
# Name: Edad_Atleta, Length: 2865, dtype: float64
# pandas.core.series.Series

# %%
display(df["Evento"])
### Otra forma de obtener la columna (pd.Series)
# df.Evento
# Out:
# 0           Men's Four/Five
# 1           Men's Four/Five
# 2           Men's Four/Five
# 3       Men's 18 Kilometers
# 4       Men's 18 Kilometers
#                ...
# 2860    Men's 50 Kilometers
# 2861    Men's 50 Kilometers
# 2862    Men's 50 Kilometers
# 2863       Men's Ice Hockey
# 2864       Men's Ice Hockey
# Name: Evento, Length: 2865, dtype: object

# %%
df[["Evento"]]
# Out:
#                    Evento
# 0         Men's Four/Five
# 1         Men's Four/Five
# 2         Men's Four/Five
# 3     Men's 18 Kilometers
# 4     Men's 18 Kilometers
# ...                   ...
# 2860  Men's 50 Kilometers
# 2861  Men's 50 Kilometers
# 2862  Men's 50 Kilometers
# 2863     Men's Ice Hockey
# 2864     Men's Ice Hockey
#
# [2865 rows x 1 columns]

# %%
df["Género"].unique()
# Out:
# array(['Men', 'Mixed', 'Women'], dtype=object)

# %%
df["Género"].value_counts()
# Out:
# Men      1711
# Women    1045
# Mixed     109
# Name: Género, dtype: int64

# %%
df["Género"].value_counts(normalize=True)
# Out:
# Men      0.597208
# Women    0.364747
# Mixed    0.038045
# Name: Género, dtype: float64

# %%
df_subset = df[["Year", "Sport", "Evento"]]
df_subset
# Out:
#       Year                 Sport               Evento
# 0     1924               Bobsled      Men's Four/Five
# 1     1924               Bobsled      Men's Four/Five
# 2     1924               Bobsled      Men's Four/Five
# 3     1924  Cross-Country Skiing  Men's 18 Kilometers
# 4     1924  Cross-Country Skiing  Men's 18 Kilometers
# ...    ...                   ...                  ...
# 2860  2014  Cross-Country Skiing  Men's 50 Kilometers
# 2861  2014  Cross-Country Skiing  Men's 50 Kilometers
# 2862  2014  Cross-Country Skiing  Men's 50 Kilometers
# 2863  2014            Ice Hockey     Men's Ice Hockey
# 2864  2014            Ice Hockey     Men's Ice Hockey
#
# [2865 rows x 3 columns]

# %%
df["Sport"].value_counts()
# Out:
# Speedskating                527
# Cross-Country Skiing        471
# Alpine Skiing               428
# Figure Skating              235
# Biathlon                    225
# Short-Track Speedskating    144
# Ski Jumping                 135
# Bobsled                     133
# Luge                        129
# Nordic Combined             102
# Freestyle Skiing            102
# Snowboarding                 90
# Ice Hockey                   81
# Curling                      33
# Skeleton                     30
# Name: Sport, dtype: int64

# %%
df["Sport"].value_counts(normalize=True, dropna=False)
# Out:
# Speedskating                0.183944
# Cross-Country Skiing        0.164398
# Alpine Skiing               0.149389
# Figure Skating              0.082024
# Biathlon                    0.078534
# Short-Track Speedskating    0.050262
# Ski Jumping                 0.047120
# Bobsled                     0.046422
# Luge                        0.045026
# Nordic Combined             0.035602
# Freestyle Skiing            0.035602
# Snowboarding                0.031414
# Ice Hockey                  0.028272
# Curling                     0.011518
# Skeleton                    0.010471
# Name: Sport, dtype: float64

# %%
df['Género'].value_counts(normalize=True, dropna=False)*100
# Out:
# Men      59.720768
# Women    36.474695
# Mixed     3.804538
# Name: Género, dtype: float64

# %% [markdown]
# ---
# ## `.loc` y `.iloc`
# ---
#
# Si deseamos seleccionar un subdataframe, con registros y columnas particulares podemos hacerlos con estas 2 funciones. `.loc` es la localización en texto y `.iloc()` será vía indexación numérica.

# %%
df.head()
# Out:
#    Year                 Sport               Evento      Country Género  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
#
#    Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# 0           1    gold           Switzerland-1          NaN
# 1           2  silver               Britain-1          NaN
# 2           3  bronze               Belgium-1          NaN
# 3           1    gold           Thorleif Haug         29.0
# 4           2  silver  Johan GrÃ¸ttumsbraaten         24.0

# %%
df["Sport"]
# Out:
# 0                    Bobsled
# 1                    Bobsled
# 2                    Bobsled
# 3       Cross-Country Skiing
# 4       Cross-Country Skiing
#                 ...
# 2860    Cross-Country Skiing
# 2861    Cross-Country Skiing
# 2862    Cross-Country Skiing
# 2863              Ice Hockey
# 2864              Ice Hockey
# Name: Sport, Length: 2865, dtype: object

# %%
df["Sport"][2860]
# Out:
# 'Cross-Country Skiing'

# %%
df.head()
# Out:
#    Year                 Sport               Evento      Country Género  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
#
#    Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# 0           1    gold           Switzerland-1          NaN
# 1           2  silver               Britain-1          NaN
# 2           3  bronze               Belgium-1          NaN
# 3           1    gold           Thorleif Haug         29.0
# 4           2  silver  Johan GrÃ¸ttumsbraaten         24.0

# %%
df.loc[4] ## Registro 4 de la tabla.
# Out:
# Year                                        1924
# Sport                       Cross-Country Skiing
# Evento                       Men's 18 Kilometers
# Country                                   Norway
# Género                                       Men
# Medal Rank                                     2
# Medalla                                   silver
# Nombre_atleta_o_Equipo    Johan GrÃ¸ttumsbraaten
# Edad_Atleta                                 24.0
# Name: 4, dtype: object

# %%
type(df.loc[4])
# Out:
# pandas.core.series.Series

# %%
df.loc[50:53] ## Registros de índice 50 a 53.
# Out:
#     Year                 Sport               Evento        Country Género  \
# 50  1928               Bobsled      Men's Four/Five  United States    Men
# 51  1928               Bobsled      Men's Four/Five        Germany    Men
# 52  1928  Cross-Country Skiing  Men's 18 Kilometers         Norway    Men
# 53  1928  Cross-Country Skiing  Men's 18 Kilometers         Norway    Men
#
#     Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# 50           2  silver         United States-1          NaN
# 51           3  bronze               Germany-2          NaN
# 52           1    gold  Johan GrÃ¸ttumsbraaten         28.0
# 53           2  silver               Ole Hegge         29.0

# %%
df.iloc[10:20] # Registros desde el 11 y hasta el 20
# Out:
#     Year           Sport           Evento        Country Género  Medal Rank  \
# 10  1924         Curling    Men's Curling         Sweden    Men           2
# 11  1924         Curling    Men's Curling         France    Men           3
# 12  1924  Figure Skating    Men's Singles         Sweden    Men           1
# 13  1924  Figure Skating    Men's Singles        Austria    Men           2
# 14  1924  Figure Skating    Men's Singles    Switzerland    Men           3
# 15  1924  Figure Skating      Mixed Pairs        Austria  Mixed           1
# 16  1924  Figure Skating      Mixed Pairs        Finland  Mixed           2
# 17  1924  Figure Skating      Mixed Pairs         France  Mixed           3
# 18  1924  Figure Skating  Women's Singles        Austria  Women           1
# 19  1924  Figure Skating  Women's Singles  United States  Women           2
#
#    Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# 10  silver                 Sweden          NaN
# ...

# %%
len(df['Year'])
# Out:
# 2865

# %%
range(len(df['Year']))
# Out:
# range(0, 2865)

# %%
# %%time
pares = []
for num in range(len(df['Year'])):
    if num%2==0:
        pares.append(num)
# Out:
# CPU times: user 839 µs, sys: 0 ns, total: 839 µs
# Wall time: 838 µs

# %%
df.loc[pares]
# Out:
#       Year                 Sport               Evento      Country Género  \
# 0     1924               Bobsled      Men's Four/Five  Switzerland    Men
# 2     1924               Bobsled      Men's Four/Five      Belgium    Men
# 4     1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 6     1924  Cross-Country Skiing  Men's 50 Kilometers       Norway    Men
# 8     1924  Cross-Country Skiing  Men's 50 Kilometers       Norway    Men
# ...    ...                   ...                  ...          ...    ...
# 2856  2014          Speedskating   Men's Team Pursuit       Poland    Men
# 2858  2014               Bobsled           Men's Four       Latvia    Men
# 2860  2014  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men
# 2862  2014  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men
# 2864  2014            Ice Hockey     Men's Ice Hockey       Sweden    Men
#
#       Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
# %%time
pares = [num for num in range(len(df["Year"])) if num%2==0]
# Out:
# CPU times: user 520 µs, sys: 0 ns, total: 520 µs
# Wall time: 531 µs

# %%
pares = [num for num in range(len(df["Year"])) if num%2==0]
df.loc[pares]
# Out:
#       Year                 Sport               Evento      Country Género  \
# 0     1924               Bobsled      Men's Four/Five  Switzerland    Men
# 2     1924               Bobsled      Men's Four/Five      Belgium    Men
# 4     1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 6     1924  Cross-Country Skiing  Men's 50 Kilometers       Norway    Men
# 8     1924  Cross-Country Skiing  Men's 50 Kilometers       Norway    Men
# ...    ...                   ...                  ...          ...    ...
# 2856  2014          Speedskating   Men's Team Pursuit       Poland    Men
# 2858  2014               Bobsled           Men's Four       Latvia    Men
# 2860  2014  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men
# 2862  2014  Cross-Country Skiing  Men's 50 Kilometers       Russia    Men
# 2864  2014            Ice Hockey     Men's Ice Hockey       Sweden    Men
#
#       Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
impares = [num for num in range(len(df['Year'])) if num%2==1]
df.iloc[impares]
# Out:
#       Year                 Sport               Evento        Country Género  \
# 1     1924               Bobsled      Men's Four/Five        Britain    Men
# 3     1924  Cross-Country Skiing  Men's 18 Kilometers         Norway    Men
# 5     1924  Cross-Country Skiing  Men's 18 Kilometers        Finland    Men
# 7     1924  Cross-Country Skiing  Men's 50 Kilometers         Norway    Men
# 9     1924               Curling        Men's Curling        Britain    Men
# ...    ...                   ...                  ...            ...    ...
# 2855  2014          Speedskating   Men's Team Pursuit    South Korea    Men
# 2857  2014               Bobsled           Men's Four         Russia    Men
# 2859  2014               Bobsled           Men's Four  United States    Men
# 2861  2014  Cross-Country Skiing  Men's 50 Kilometers         Russia    Men
# 2863  2014            Ice Hockey     Men's Ice Hockey         Canada    Men
#
# ...

# %%
df[['Sport','Evento']]
# Out:
#                      Sport               Evento
# 0                  Bobsled      Men's Four/Five
# 1                  Bobsled      Men's Four/Five
# 2                  Bobsled      Men's Four/Five
# 3     Cross-Country Skiing  Men's 18 Kilometers
# 4     Cross-Country Skiing  Men's 18 Kilometers
# ...                    ...                  ...
# 2860  Cross-Country Skiing  Men's 50 Kilometers
# 2861  Cross-Country Skiing  Men's 50 Kilometers
# 2862  Cross-Country Skiing  Men's 50 Kilometers
# 2863            Ice Hockey     Men's Ice Hockey
# 2864            Ice Hockey     Men's Ice Hockey
#
# [2865 rows x 2 columns]

# %%
pares[:5]
# Out:
# [0, 2, 4, 6, 8]

# %%
df.loc[pares, ["Sport","Evento"]]
# Out:
#                      Sport               Evento
# 0                  Bobsled      Men's Four/Five
# 2                  Bobsled      Men's Four/Five
# 4     Cross-Country Skiing  Men's 18 Kilometers
# 6     Cross-Country Skiing  Men's 50 Kilometers
# 8     Cross-Country Skiing  Men's 50 Kilometers
# ...                    ...                  ...
# 2856          Speedskating   Men's Team Pursuit
# 2858               Bobsled           Men's Four
# 2860  Cross-Country Skiing  Men's 50 Kilometers
# 2862  Cross-Country Skiing  Men's 50 Kilometers
# 2864            Ice Hockey     Men's Ice Hockey
#
# [1433 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Sport', 'Evento', 'Country', 'Género', 'Medal Rank', 'Medalla',
#        'Nombre_atleta_o_Equipo', 'Edad_Atleta'],
#       dtype='object')

# %%
for num,column in enumerate(df.columns):
    print((num, column))
# Out:
# (0, 'Year')
# (1, 'Sport')
# (2, 'Evento')
# (3, 'Country')
# (4, 'Género')
# (5, 'Medal Rank')
# (6, 'Medalla')
# (7, 'Nombre_atleta_o_Equipo')
# (8, 'Edad_Atleta')

# %%
df.iloc[impares, [0, 1, 8]]
# Out:
#       Year                 Sport  Edad_Atleta
# 1     1924               Bobsled          NaN
# 3     1924  Cross-Country Skiing         29.0
# 5     1924  Cross-Country Skiing         28.0
# 7     1924  Cross-Country Skiing         27.0
# 9     1924               Curling          NaN
# ...    ...                   ...          ...
# 2855  2014          Speedskating          NaN
# 2857  2014               Bobsled          NaN
# 2859  2014               Bobsled          NaN
# 2861  2014  Cross-Country Skiing         31.0
# 2863  2014            Ice Hockey          NaN
#
# [1432 rows x 3 columns]

# %% [markdown]
# ---
# ## Máscaras
# ---
# Supongamos que deseamos obtener los regístros que cumplen cierta condición. Por ejemplo, todos aquellos donde el género sea mujer, las personas menores de 30 años, aquellos que ganaron plata, o quizá mujeres que ganaron plata y son menores de 30 años.
#
# Para hacer esto necesitamos una serie de `pandas` de tipo booleano, que determina que registros cumplen la condición deseada.

# %%
df.head()
# Out:
#    Year                 Sport               Evento      Country Género  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
#
#    Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# 0           1    gold           Switzerland-1          NaN
# 1           2  silver               Britain-1          NaN
# 2           3  bronze               Belgium-1          NaN
# 3           1    gold           Thorleif Haug         29.0
# 4           2  silver  Johan GrÃ¸ttumsbraaten         24.0

# %%
df.tail()
# Out:
#       Year                 Sport               Evento Country Género  \
# 2860  2014  Cross-Country Skiing  Men's 50 Kilometers  Russia    Men
# 2861  2014  Cross-Country Skiing  Men's 50 Kilometers  Russia    Men
# 2862  2014  Cross-Country Skiing  Men's 50 Kilometers  Russia    Men
# 2863  2014            Ice Hockey     Men's Ice Hockey  Canada    Men
# 2864  2014            Ice Hockey     Men's Ice Hockey  Sweden    Men
#
#       Medal Rank Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# 2860           1    gold       Alexander Legkov         30.0
# 2861           2  silver      Maxim Vylegzhanin         31.0
# 2862           3  bronze        Ilia Chernousov         27.0
# 2863           1    gold                 Canada          NaN
# 2864           2  silver                 Sweden          NaN

# %%
mask = (df["Year"] == 1924)
df[mask]

# %%
df.query("Year == 1924 or Year == 1950")

# %%
mask = (df["Year"] == 1924)
mask1 = (df["Year"] == 1952)
df[mask | mask1]
# Out:
#      Year                 Sport               Evento      Country Género  \
# 0    1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1    1924               Bobsled      Men's Four/Five      Britain    Men
# 2    1924               Bobsled      Men's Four/Five      Belgium    Men
# 3    1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4    1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# ..    ...                   ...                  ...          ...    ...
# 313  1952          Speedskating   Men's 5,000 Meters  Netherlands    Men
# 314  1952          Speedskating   Men's 5,000 Meters       Norway    Men
# 315  1952          Speedskating  Men's 10,000 Meters       Norway    Men
# 316  1952          Speedskating  Men's 10,000 Meters  Netherlands    Men
# 317  1952          Speedskating  Men's 10,000 Meters       Sweden    Men
#
#      Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
## Tenemos todos los registros de quienes ganaron medalla después del Año 1948
df[mask]
# Out:
#       Year                 Sport               Evento  Country Género  \
# 251   1952         Alpine Skiing       Men's Downhill    Italy    Men
# 252   1952         Alpine Skiing       Men's Downhill  Austria    Men
# 253   1952         Alpine Skiing       Men's Downhill  Austria    Men
# 254   1952         Alpine Skiing   Men's Giant Slalom   Norway    Men
# 255   1952         Alpine Skiing   Men's Giant Slalom  Austria    Men
# ...    ...                   ...                  ...      ...    ...
# 2860  2014  Cross-Country Skiing  Men's 50 Kilometers   Russia    Men
# 2861  2014  Cross-Country Skiing  Men's 50 Kilometers   Russia    Men
# 2862  2014  Cross-Country Skiing  Men's 50 Kilometers   Russia    Men
# 2863  2014            Ice Hockey     Men's Ice Hockey   Canada    Men
# 2864  2014            Ice Hockey     Men's Ice Hockey   Sweden    Men
#
#       Medal Rank Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# 251            1    gold             Zeno ColÃ²         31.0
# ...

# %%
mask_1 = (df['Edad_Atleta'] <= 20)

# %%
df_menores_de_20 = df[mask_1]
display(df_menores_de_20.describe().T)
df_menores_de_20.head()
# Out:
#              count         mean        std     min     25%     50%     75%  \
# Year         299.0  1983.471572  22.087115  1924.0  1968.0  1984.0  2002.0
# Medal Rank   299.0     2.023411   0.812726     1.0     1.0     2.0     3.0
# Edad_Atleta  299.0    18.856187   1.332123    14.0    18.0    19.0    20.0
#
#                 max
# Year         2014.0
# Medal Rank      3.0
# Edad_Atleta    20.0
#     Year           Sport           Evento        Country Género  Medal Rank  \
# 14  1924  Figure Skating    Men's Singles    Switzerland    Men           3
# 60  1928  Figure Skating    Men's Singles        Belgium    Men           3
# 64  1928  Figure Skating  Women's Singles         Norway  Women           1
# 65  1928  Figure Skating  Women's Singles        Austria  Women           2
# 74  1928        Skeleton   Men's Skeleton  United States    Men           2
#
#    Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# 14  bronze       Georges Gautschi         19.0
# ...

# %%
df_menores_de_20.describe(include=["object"]).T
# Out:
#                        count unique               top freq
# Sport                    299     12     Alpine Skiing   67
# Evento                   299     45   Women's Singles   46
# Country                  299     33     United States   58
# Género                   299      2             Women  164
# Medalla                  299      3            bronze  102
# Nombre_atleta_o_Equipo   299    250  Janica KosteliÄ‡    4

# %%
df_menores_de_20
# Out:
#       Year                     Sport                Evento        Country  \
# 14    1924            Figure Skating         Men's Singles    Switzerland
# 60    1928            Figure Skating         Men's Singles        Belgium
# 64    1928            Figure Skating       Women's Singles         Norway
# 65    1928            Figure Skating       Women's Singles        Austria
# 74    1928                  Skeleton        Men's Skeleton  United States
# ...    ...                       ...                   ...            ...
# 2814  2014             Alpine Skiing        Women's Slalom  United States
# 2827  2014  Short-Track Speedskating  Women's 1,000 Meters          China
# 2828  2014  Short-Track Speedskating  Women's 1,000 Meters    South Korea
# 2830  2014  Short-Track Speedskating      Men's 500 Meters          China
# 2837  2014             Alpine Skiing          Men's Slalom         Norway
#
#      Género  Medal Rank Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
df_menores_de_20.reset_index(drop=True)
# Out:
#      Year                     Sport                Evento        Country  \
# 0    1924            Figure Skating         Men's Singles    Switzerland
# 1    1928            Figure Skating         Men's Singles        Belgium
# 2    1928            Figure Skating       Women's Singles         Norway
# 3    1928            Figure Skating       Women's Singles        Austria
# 4    1928                  Skeleton        Men's Skeleton  United States
# ..    ...                       ...                   ...            ...
# 294  2014             Alpine Skiing        Women's Slalom  United States
# 295  2014  Short-Track Speedskating  Women's 1,000 Meters          China
# 296  2014  Short-Track Speedskating  Women's 1,000 Meters    South Korea
# 297  2014  Short-Track Speedskating      Men's 500 Meters          China
# 298  2014             Alpine Skiing          Men's Slalom         Norway
#
#     Género  Medal Rank Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
df_menores_de_20.reset_index(drop=True, inplace=True)
df_menores_de_20
# Out:
#      Year                     Sport                Evento        Country  \
# 0    1924            Figure Skating         Men's Singles    Switzerland
# 1    1928            Figure Skating         Men's Singles        Belgium
# 2    1928            Figure Skating       Women's Singles         Norway
# 3    1928            Figure Skating       Women's Singles        Austria
# 4    1928                  Skeleton        Men's Skeleton  United States
# ..    ...                       ...                   ...            ...
# 294  2014             Alpine Skiing        Women's Slalom  United States
# 295  2014  Short-Track Speedskating  Women's 1,000 Meters          China
# 296  2014  Short-Track Speedskating  Women's 1,000 Meters    South Korea
# 297  2014  Short-Track Speedskating      Men's 500 Meters          China
# 298  2014             Alpine Skiing          Men's Slalom         Norway
#
#     Género  Medal Rank Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
df_menores_de_20.set_index(keys=["Country"])
# Out:
#                Year                     Sport                Evento Género  \
# Country
# Switzerland    1924            Figure Skating         Men's Singles    Men
# Belgium        1928            Figure Skating         Men's Singles    Men
# Norway         1928            Figure Skating       Women's Singles  Women
# Austria        1928            Figure Skating       Women's Singles  Women
# United States  1928                  Skeleton        Men's Skeleton    Men
# ...             ...                       ...                   ...    ...
# United States  2014             Alpine Skiing        Women's Slalom  Women
# China          2014  Short-Track Speedskating  Women's 1,000 Meters  Women
# South Korea    2014  Short-Track Speedskating  Women's 1,000 Meters  Women
# China          2014  Short-Track Speedskating      Men's 500 Meters    Men
# Norway         2014             Alpine Skiing          Men's Slalom    Men
#
# ...

# %%
## Podemos juntar ambas condiciones
df[mask & mask_1].describe().T
# Out:
#              count         mean        std     min     25%     50%     75%  \
# Year         276.0  1987.427536  17.869990  1952.0  1972.0  1992.0  2002.0
# Medal Rank   276.0     2.018116   0.815552     1.0     1.0     2.0     3.0
# Edad_Atleta  276.0    18.880435   1.308788    14.0    18.0    19.0    20.0
#
#                 max
# Year         2014.0
# Medal Rank      3.0
# Edad_Atleta    20.0

# %%
df["Medalla"].value_counts()
# Out:
# gold      959
# silver    958
# bronze    948
# Name: Medalla, dtype: int64

# %%
## informació para un segmento particular.
df[mask & mask_1]['Medalla'].value_counts()
# Out:
# bronze    94
# silver    93
# gold      89
# Name: Medalla, dtype: int64

# %%
mask_2 = df['Country'] == 'China'
df[mask_1 & mask_1 & mask_2].reset_index(drop=True)["Género"].value_counts(normalize=True)*100
# Out:
# Women    75.0
# Men      25.0
# Name: Género, dtype: float64

# %% [markdown]
# ---
# ## NaN
# ---
# Suele ocurrir que en nuestro `dataframe` se tengan valores perdidos. Estos deben ser tratados por métodos de imputación que mas adelante discutiremos. Por ahora veremos como eliminarlos o modificarlos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2865 entries, 0 to 2864
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    2865 non-null   int64
#  1   Sport                   2865 non-null   object
#  2   Evento                  2865 non-null   object
#  3   Country                 2865 non-null   object
#  4   Género                  2865 non-null   object
#  5   Medal Rank              2865 non-null   int64
#  6   Medalla                 2865 non-null   object
#  7   Nombre_atleta_o_Equipo  2865 non-null   object
#  8   Edad_Atleta             2173 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 201.6+ KB

# %%
df_drop = df.dropna()
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2173 entries, 3 to 2862
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    2173 non-null   int64
#  1   Sport                   2173 non-null   object
#  2   Evento                  2173 non-null   object
#  3   Country                 2173 non-null   object
#  4   Género                  2173 non-null   object
#  5   Medal Rank              2173 non-null   int64
#  6   Medalla                 2173 non-null   object
#  7   Nombre_atleta_o_Equipo  2173 non-null   object
#  8   Edad_Atleta             2173 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 169.8+ KB

# %%
df_drop = df.dropna(subset=["Edad_Atleta"])
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2173 entries, 3 to 2862
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    2173 non-null   int64
#  1   Sport                   2173 non-null   object
#  2   Evento                  2173 non-null   object
#  3   Country                 2173 non-null   object
#  4   Género                  2173 non-null   object
#  5   Medal Rank              2173 non-null   int64
#  6   Medalla                 2173 non-null   object
#  7   Nombre_atleta_o_Equipo  2173 non-null   object
#  8   Edad_Atleta             2173 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 169.8+ KB

# %%
print(df.shape, df_drop.shape)
# Out:
# (2865, 9) (2173, 9)

# %%
df["Edad_Atleta"].isna()
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2860    False
# 2861    False
# 2862    False
# 2863     True
# 2864     True
# Name: Edad_Atleta, Length: 2865, dtype: bool

# %%
df[df['Edad_Atleta'].isna()]
# Out:
#       Year       Sport            Evento        Country Género  Medal Rank  \
# 0     1924     Bobsled   Men's Four/Five    Switzerland    Men           1
# 1     1924     Bobsled   Men's Four/Five        Britain    Men           2
# 2     1924     Bobsled   Men's Four/Five        Belgium    Men           3
# 9     1924     Curling     Men's Curling        Britain    Men           1
# 10    1924     Curling     Men's Curling         Sweden    Men           2
# ...    ...         ...               ...            ...    ...         ...
# 2857  2014     Bobsled        Men's Four         Russia    Men           1
# 2858  2014     Bobsled        Men's Four         Latvia    Men           2
# 2859  2014     Bobsled        Men's Four  United States    Men           3
# 2863  2014  Ice Hockey  Men's Ice Hockey         Canada    Men           1
# 2864  2014  Ice Hockey  Men's Ice Hockey         Sweden    Men           2
#
#      Medalla Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
df['Edad_Atleta'].isna()
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2860    False
# 2861    False
# 2862    False
# 2863     True
# 2864     True
# Name: Edad_Atleta, Length: 2865, dtype: bool

# %%
~(df['Edad_Atleta'].isna())
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 2860     True
# 2861     True
# 2862     True
# 2863    False
# 2864    False
# Name: Edad_Atleta, Length: 2865, dtype: bool

# %%
## Podemos obtener la negación de la máscara
df[~(df['Edad_Atleta'].isna())]
# Out:
#       Year                 Sport                 Evento   Country Género  \
# 3     1924  Cross-Country Skiing    Men's 18 Kilometers    Norway    Men
# 4     1924  Cross-Country Skiing    Men's 18 Kilometers    Norway    Men
# 5     1924  Cross-Country Skiing    Men's 18 Kilometers   Finland    Men
# 6     1924  Cross-Country Skiing    Men's 50 Kilometers    Norway    Men
# 7     1924  Cross-Country Skiing    Men's 50 Kilometers    Norway    Men
# ...    ...                   ...                    ...       ...    ...
# 2849  2014          Snowboarding  Men's Parallel Slalom  Slovenia    Men
# 2850  2014          Snowboarding  Men's Parallel Slalom   Austria    Men
# 2860  2014  Cross-Country Skiing    Men's 50 Kilometers    Russia    Men
# 2861  2014  Cross-Country Skiing    Men's 50 Kilometers    Russia    Men
# 2862  2014  Cross-Country Skiing    Men's 50 Kilometers    Russia    Men
#
#       Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta
# ...

# %%
## Todo regístro None o NaN es reemplazado por 0
df.fillna(0).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2865 entries, 0 to 2864
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    2865 non-null   int64
#  1   Sport                   2865 non-null   object
#  2   Evento                  2865 non-null   object
#  3   Country                 2865 non-null   object
#  4   Género                  2865 non-null   object
#  5   Medal Rank              2865 non-null   int64
#  6   Medalla                 2865 non-null   object
#  7   Nombre_atleta_o_Equipo  2865 non-null   object
#  8   Edad_Atleta             2865 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 201.6+ KB

# %%
df['Edad_Atleta_imputado'] = df['Edad_Atleta'].fillna(df['Edad_Atleta'].mean())
df.head(10)
# Out:
#    Year                 Sport               Evento      Country Género  \
# 0  1924               Bobsled      Men's Four/Five  Switzerland    Men
# 1  1924               Bobsled      Men's Four/Five      Britain    Men
# 2  1924               Bobsled      Men's Four/Five      Belgium    Men
# 3  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 4  1924  Cross-Country Skiing  Men's 18 Kilometers       Norway    Men
# 5  1924  Cross-Country Skiing  Men's 18 Kilometers      Finland    Men
# 6  1924  Cross-Country Skiing  Men's 50 Kilometers       Norway    Men
# 7  1924  Cross-Country Skiing  Men's 50 Kilometers       Norway    Men
# 8  1924  Cross-Country Skiing  Men's 50 Kilometers       Norway    Men
# 9  1924               Curling        Men's Curling      Britain    Men
#
#    Medal Rank Medalla  Nombre_atleta_o_Equipo  Edad_Atleta  \
# 0           1    gold           Switzerland-1          NaN
# 1           2  silver               Britain-1          NaN
# ...

# %%
df_drop.shape
# Out:
# (2173, 9)

# %% [markdown]
# ---
# ## `pandas.crosstab`
# ---
# La función `pandas.crosstab` devuelve la tabla de contingencia resultante de cruzar dos o más columnas de un dataframe. Por defecto ell resultado evalúa las frecuencias (absolutas o relativas) de cada combinación de valores, es posible especificar una función de agregación.

# %%
pd.crosstab(df['Género'], df['Medalla'], )
# Out:
# Medalla  bronze  gold  silver
# Género
# Men         568   573     570
# Mixed        36    37      36
# Women       344   349     352

# %%
## Podemos obtener la suma por filas y columnas (subtotales) y renombrar esta
pd.crosstab(df['Género'], df['Medalla'], margins=True, margins_name='Total',)
# Out:
# Medalla  bronze  gold  silver  Total
# Género
# Men         568   573     570   1711
# Mixed        36    37      36    109
# Women       344   349     352   1045
# Total       948   959     958   2865

# %%
## Podemos mostrar las frecuencias 'normalizadas' (es decir una parte de la unidad). Se puede obtener respecto al total o con respecto a los subtotales
## de filas o columnas. Asignamos al parámetro normalize el valor True, la normalización se realiza con respecto al total de muestras
pd.crosstab(df['Género'],df['Medalla'], normalize=True)
# Out:
# Medalla    bronze      gold    silver
# Género
# Men      0.198255  0.200000  0.198953
# Mixed    0.012565  0.012914  0.012565
# Women    0.120070  0.121815  0.122862

# %% [markdown]
# Del total de las medallas entregadas:
#
# 1.   19.8% fueron de bronce y entregas a hombres.
# 2.   12.2% fueron de plata y entregadas a mujeres.
#
# En cada casilla podemos extraer información similar.

# %%
pd.crosstab(df['Género'],df['Medalla'], normalize=True, margins=True, margins_name= 'Total %')
# Out:
# Medalla    bronze      gold    silver   Total %
# Género
# Men      0.198255  0.200000  0.198953  0.597208
# Mixed    0.012565  0.012914  0.012565  0.038045
# Women    0.120070  0.121815  0.122862  0.364747
# Total %  0.330890  0.334729  0.334380  1.000000

# %%
pd.crosstab(df['Género'], df['Country'])
# Out:
# Country  Australia  Austria  Belarus  Belgium  Britain  Bulgaria  Canada  \
# Género
# Men              5      143        8        4       13         1      82
# Mixed            0        5        0        1        2         0      11
# Women            7       70        7        0       11         5      77
#
# Country  China  Croatia  Czech Republic  Czechoslovakia  Denmark  \
# Género
# Men         12        5               9              19        0
# Mixed        5        0               1               0        0
# Women       36        6              14               6        1
#
# Country  East Germany  Estonia  Finland  France  Germany  Hungary  Italy  \
# Género
# Men                62        4      119      65       97        0     73
# Mixed               4        0        1       6        8        6      2
# Women              44        3       41      38      123        0     39
#
# Country  Japan  Kazakhstan  Latvia  Liechtenstein  Luxembourg  Netherlands  \
# Género
# ...

# %%
## Revisar
pais_genero = pd.DataFrame(pd.crosstab(df['Género'], df['Country']).unstack()).rename({0:'Conteo'},axis=1)
pais_genero.head(10)
# Out:
#                   Conteo
# Country   Género
# Australia Men          5
#           Mixed        0
#           Women        7
# Austria   Men        143
#           Mixed        5
#           Women       70
# Belarus   Men          8
#           Mixed        0
#           Women        7
# Belgium   Men          4

# %%
pais_genero.loc['Belgium']
# Out:
#         Conteo
# Género
# Men          4
# Mixed        1
# Women        0

# %% [markdown]
# ### ***Archivos SPSS***

# %%
# !ls "data"
# Out:
#  Athelete_Country_Map.csv   downloaded_medals.csv    Medals.csv
#  Athelete_Sports_Map.csv    downloaded_medals.json   mi_descarga.xlsx
#  CARS2005.SAV               downloaded_medals.xls   'Winter Olympic Medals.xlsx'

# %%
# %%capture
# !pip install pyreadstat

# %%
## Archivos de datos SPSS
df_spss = pd.read_spss("../data/CARS2005.SAV")
df_spss
# Out:
#               Brand                   Model  Minivan  Wagon  Pickup  \
# 0            TOYOTA                   Prius      0.0    0.0     0.0
# 1             HONDA            Civic Hybrid      0.0    0.0     0.0
# 2             HONDA            Civic Hybrid      0.0    0.0     0.0
# 3             HONDA            Civic Hybrid      0.0    0.0     0.0
# 4             HONDA            Civic Hybrid      0.0    0.0     0.0
# ...             ...                     ...      ...    ...     ...
# 1076     LAND ROVER             Range Rover      0.0    0.0     0.0
# 1077  MERCEDES-BENZ                 G55 AMG      0.0    0.0     0.0
# 1078      CHEVROLET  C2500 HD Silverado 2WD      0.0    0.0     1.0
# 1079            GMC     C2500 HD Sierra 2WD      0.0    0.0     1.0
# 1080        PORSCHE              Carrera GT      0.0    0.0     0.0
#
#       Automatic  EngineSize  Cylinders  CityMPG  HwyMPG  SUV AWD  Hybrid
# 0           1.0         1.5        4.0     60.0    51.0   No  No     1.0
# ...

# %% [markdown]
# ### ***Tablas de Wikipedia***

# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

url = "https://es.wikipedia.org/wiki/Chicago_Bulls"
r = requests.get(url)
print(f"Response get --> {r}")
# Out:
# Response get --> <Response [200]>

# %%
soup = BeautifulSoup(r.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Chicago Bulls - Wikipedia, la enciclopedia libre
#   </title>
#   <script>
# ...

# %% [markdown]
# ### ***Tabla with BeautifulSoup.***

# %%
soup.find_all('table')
# Out:
# [<table class="infobox plainlist" style="width:22.7em; line-height: 1.4em; text-align:left; padding:.23em;"><tbody><tr><th class="cabecera baloncesto" colspan="3" style="text-align:center;background-color:#CCCC88;color:inherit;background-color: #CE1141;color:white;">Chicago Bulls</th></tr><tr><td class="imagen" colspan="3" style="text-align:center;font-size: 92%;;">
# ...

# %%
print(type(soup.find_all('table')))
tables = [x for x in soup.find_all('table')]
# Out:
# <class 'bs4.element.ResultSet'>

# %%
lista = []
for i in tables[0].find_all('tr'):
    try:
        i.find('td').get_text()
    except:
        lista.append(np.nan)
    else:
        lista.append(i.find('td').get_text())
#lista, len(lista)

# %%
lista1 = []
for i in tables[0].find_all('tr'):
    try:
        i.find('th').get_text()
    except:
        lista1.append(np.nan)
    else:
        lista1.append(i.find('th').get_text())
#lista1, len(lista1)

# %%
dicc = dict(zip(lista1, lista))
pd.DataFrame(dicc.items(), columns=['categoria', 'info'])
# Out:
#                  categoria                                               info
# 0            Chicago Bulls                                                NaN
# 1                      NaN                         [editar datos en Wikidata]
# 2          Datos generales                                                NaN
# 3                  Mascota                                   \nBenny the Bull
# 4                  Deporte                                       \nBaloncesto
# 5                Fundación                    \n16 de enero de 1966 (58 años)
# 6                  Colores           \nRojo, negro y blanco\n\n
# 7           Propietario(s)                                 \n Jerry Reinsdorf
# 8               Presidente                               \n Michael Reinsdorf
# 9          Mánager general                                   \n Marc Eversley
# 10              Entrenador                                   \n Billy Donovan
# ...

# %%
result = pd.DataFrame(list(zip(lista1, lista)), columns=['col1', 'col2'])
result['col2'] = result['col2'].apply(lambda x: str(x).replace('\n',""))
result = result.dropna(subset=['col1'])
result
# Out:
#                       col1                                               col2
# 0            Chicago Bulls                                                nan
# 2          Datos generales                                                nan
# 3                  Mascota                                     Benny the Bull
# 4                  Deporte                                         Baloncesto
# 5                Fundación                      16 de enero de 1966 (58 años)
# 6                  Colores                 Rojo, negro y blanco
# 7           Propietario(s)                                    Jerry Reinsdorf
# 8               Presidente                                  Michael Reinsdorf
# 9          Mánager general                                      Marc Eversley
# 10              Entrenador                                      Billy Donovan
# 11         Equipo afiliado                                   Windy City Bulls
# ...

# %%
## Tablas de wikipedia
df_wiki = pd.read_html("https://es.wikipedia.org/wiki/Chicago_Bulls", )
for number, df in enumerate(df_wiki):
    print(f"Dataframe obtenido número {number+1}")
    display(df.head(5))
# Out:
# Dataframe obtenido número 1
#      Chicago Bulls                Chicago Bulls.1  \
# 0              NaN                            NaN
# 1  Datos generales                Datos generales
# 2          Mascota                 Benny the Bull
# 3          Deporte                     Baloncesto
# 4        Fundación  16 de enero de 1966 (58 años)
#
#                  Chicago Bulls.2
# 0                            NaN
# 1                Datos generales
# 2                 Benny the Bull
# 3                     Baloncesto
# 4  16 de enero de 1966 (58 años)
# Dataframe obtenido número 2
#        Temporada              G              P              %  \
# 0  Chicago Bulls  Chicago Bulls  Chicago Bulls  Chicago Bulls
# 1        1966-67             33             49           .407
# 2        1967-68             29             53           .354
# 3        1968-69             33             49           .402
# 4        1969-70             39             43           .476
#
# ...
